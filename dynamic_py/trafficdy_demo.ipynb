# %%
import numpy as np
import pandas as pd
import sklearn

# %%
# read the data file and transfer into DataFrame
raw_data = pd.read_csv('NGSIM__Lankershim_Vehicle_Trajectories.csv')
raw_df = pd.DataFrame(raw_data)
raw_df
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames   Global_Time  Local_X   Local_Y  \
# 0                63         3           394  1.120000e+12   44.589    67.404
# 1                64         3           507  1.120000e+12   14.388    35.678
# 2                63         4           394  1.120000e+12   44.589    67.404
# 3                64         4           507  1.120000e+12   14.561    40.175
# 4                63         5           394  1.120000e+12   44.624    67.904
# ...             ...       ...           ...           ...      ...       ...
# 1048570         571      4753          1744  1.120000e+12   32.769  1593.169
# 1048571         571      4754          1744  1.120000e+12   32.816  1595.553
# 1048572         571      4755          1744  1.120000e+12   32.824  1598.478
# 1048573         571      4756          1744  1.120000e+12   32.812  1601.832
# 1048574         571      4757          1744  1.120000e+12   32.577  1604.737
#
# ...

# %%
# select intersection 1 & southbound
# Direction: 1E2NeW4S
# Movement: 1TH, 2LT, 3RT

int1_df = raw_df.loc[(raw_df['Int_ID'] == 1)]
int1s_df = int1_df.loc[(raw_df['Movement'] == 1) |
                     (raw_df['Movement'] == 2)]
int1s_df
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames   Global_Time  Local_X  Local_Y  \
# 1                64         3           507  1.120000e+12   14.388   35.678
# 3                64         4           507  1.120000e+12   14.561   40.175
# 5                64         5           507  1.120000e+12   14.715   44.172
# 7                64         6           507  1.120000e+12   14.850   47.670
# 9                64         7           507  1.120000e+12   15.024   52.167
# ...             ...       ...           ...           ...      ...      ...
# 1035194         649      3928           454  1.120000e+12   -6.775   61.218
# 1035229         649      3929           454  1.120000e+12   -6.794   58.366
# 1035264         649      3930           454  1.120000e+12   -6.814   55.526
# 1035299         649      3931           454  1.120000e+12   -6.765   52.478
# 1035334         649      3932           454  1.120000e+12   -6.699   49.638
#
# ...

# %%
# sort the global time

int1s_df['Global_Time']
# float64 cannot show the precise value of Global Time
# need to normalise the time value
# Out:
# 1          1.120000e+12
# 3          1.120000e+12
# 5          1.120000e+12
# 7          1.120000e+12
# 9          1.120000e+12
#                ...
# 1035194    1.120000e+12
# 1035229    1.120000e+12
# 1035264    1.120000e+12
# 1035299    1.120000e+12
# 1035334    1.120000e+12
# Name: Global_Time, Length: 18946, dtype: float64
